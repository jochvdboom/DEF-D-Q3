# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Zahra Ramdame| 6533183 |
# | Mehraj Khalid| 6590276 |
# | Jochem van den Boomen| 6527620 |
# | Planning Groep: 48     |Tijdstip / Tijdspanne  |
# |---|---|
# | Sanity checks | 12:00 |
# | condensator af | 16:30 |
# | groep aanwezig 1| Tijdspanne |
# | groep aanwezig 2| Tijdspanne |
# | Pauze 1| 12:30 - 13:30 |
# | Pauze 2| Tijdspanne |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="foto_schets_condensator.jpg" alt="schets student 1" width="400"/>
# <img src="foto_afleiding.jpeg" alt="schets student 1" width="400"/>
#
#
# Dit zijn de oude foto's die verbeterd zijn nu. Om een of andere reden willen de nieuwe foto's niet laden maar die zijn wel in de map aanwezig. Deze foto's kloppen dus niet met de huidige opstelling.

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
epsilon_0 = 8.854187817e-12
epsilon_r = 3
oppervlakte = 0.00992
afstand = 0.001

def capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r):
    return epsilon_0 * epsilon_r * oppervlakte / afstand

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r)

print(f"Berekende capaciteit plaatcondensator groep 48 is {C*1e12:.1f} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 48 is 263.5 pF

# %%
import math

def bereken_capaciteit(Voutpeak, Vp, f, R):
    return Voutpeak / (Vp * 2 * math.pi * f * R)

Voutpeak = 1.4   # Volt
Vp = 8           # Volt
f = 100000         # Hz
R = 1000         # Ohm

C = bereken_capaciteit(Voutpeak, Vp, f, R)

print(f"Capaciteit van onze zelfgemaakte condensator is {C*1e12:.1f} pF")
# Out:
# Capaciteit van onze zelfgemaakte condensator is 278.5 pF

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](foto_opstelling.jpeg)
# ![scope meting 2](foto_apperatuur.jpeg)
#
# Dit zijn de oude foto's die verbeterd zijn nu. Om een of andere reden willen de nieuwe foto's niet laden maar die zijn wel in de map aanwezig. Deze foto's kloppen dus niet met de huidige opstelling.

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 48| 263.5 pF |1.02 V | 0.87 V | 173.1 pF |

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](foto_schetsen_synthese.jpeg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Wij gaan een sensor maken die druk meet.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](foto_schets_uiteindelijkeopstelling.jpeg)

# %%
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import numpy as np
import matplotlib.pyplot as plt

g = 9.81

# Afstanden in meter
afstand_0 = 1.2 / 100
afstand_1 = 1.1 / 100
afstand_2 = 1.0 / 100
afstand_3 = 0.9 / 100

# Massa's in kg
massa_0 = 0
massa_1 = 0.965 + 0.964 + 0.574
massa_2 = 0.965 + 0.964 + 0.574 + 0.4892
massa_3 = 0.965 + 0.964 + 0.574 + 0.9508 + 0.4892 + 0.4827 + 0.9738

massa = np.array([massa_1, massa_2, massa_3])
afstand = np.array([afstand_1, afstand_2, afstand_3])

# Indeuking
delta_x = afstand_0 - afstand

# Kracht
F = massa * g

# Veerconstante per meting
k = F / delta_x

# Gemiddelde veerconstante
k_gemiddeld = np.mean(k)

print("Veerconstante per meting (N/m):", k)
print("Gemiddelde veerconstante (N/m):", k_gemiddeld)
print("de gevonden waarde is veel hoger dan dat je zou verwachten, aangezien een normale huispons een veerconstante heeft tussen de 300 en 500 N/m. Deze hoge waarde kan worden verklaard doordat we relatief kleine massa's gebruiken en het aan het begin moeilijker is om de spons in te duwen, waardoor de gemeten veerconstante hoger uitvalt.")
# Out:
# Veerconstante per meting (N/m): [24554.43  14676.741 17656.365]
# Gemiddelde veerconstante (N/m): 18962.512000000006
# de gevonden waarde is veel hoger dan dat je zou verwachten, aangezien een normale huispons een veerconstante heeft tussen de 300 en 500 N/m. Deze hoge waarde kan worden verklaard doordat we relatief kleine massa's gebruiken en het aan het begin moeilijker is om de spons in te duwen, waardoor de gemeten veerconstante hoger uitvalt.

# %%
import numpy as np
import matplotlib.pyplot as plt

epsilon_0 = 8.854187817e-12
epsilon_r = 1.5
oppervlakte = 0.00992
afstand_0 = 1.2 / 100  # 1.2 cm → meter

k = k_gemiddeld
g = 9.81

def capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r):
    return epsilon_0 * epsilon_r * oppervlakte / afstand

# Massa's van 0 tot 6 kg
massa = np.linspace(0, 6, 100)

# Bereken indeuking
delta_x = (massa * g) / k

# Nieuwe afstand
afstand = afstand_0 - delta_x

# Voorkom negatieve afstanden
afstand[afstand <= 0] = 1e-6

# Bereken capaciteit (in Farad)
C = capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r)

# Omzetten naar picoFarad
C_pF = C * 1e12

# Plot indeuking tegen capaciteit in pF
plt.plot(delta_x, C_pF)
plt.xlabel("Indeuking (m)")
plt.ylabel("Capaciteit (pF)")
plt.title("Indeuking vs Capaciteit")
plt.show()

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 10 |20 |
# | gemiddelde capaciteit| 12.5 |40 |
# | maximale capaciteit| 15 |60 |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](foto_opstelling_1zak.jpeg)
# ![gegevens 1](foto_resultaat_1zak.jpeg)
# ![meting 2](foto_opstelling_2zakken.jpeg)
# ![gegevens 2](foto_resultaat_2zakken.jpeg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
epsilon_0 = 8.854187817e-12
epsilon_r_spons = 1.5
oppervlakte = 0.01
afstand_0 = 1.2 / 100  

g = 9.81

gebruikte_massas  =  np.array([964, 1446.7, 2397.5, 2971.5, 3460.7, 4425.1, 5398.9, 6361.9 ]) / 1000
capaciteit = np.array([14.7, 16.9, 23.1, 26.4, 28.9, 32.6, 36.2, 40.2 ]) * 1e-12


# Bereken indeuking
delta_x_spons = (gebruikte_massas * g) / k_gemiddeld

# Nieuwe afstand
afstand_spons = afstand_0 - delta_x_spons

# Voorkom negatieve afstanden
afstand_spons[afstand_spons <= 0] = 1e-6

# Omzetten naar picoFarad
capaciteit_pF = capaciteit * 1e12

def capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r_spons):
    return epsilon_0 * epsilon_r_spons * oppervlakte / afstand

# Massa's van 0 tot 6 kg
massa = np.linspace(0, 6, 100)

# Bereken indeuking
delta_x = (massa * g) / k_gemiddeld

# Nieuwe afstand
afstand = afstand_0 - delta_x

# Voorkom negatieve afstanden
afstand[afstand <= 0] = 1e-6

# Bereken capaciteit (in Farad)
C = capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r_spons)

# Omzetten naar picoFarad
C_pF = C * 1e12

sigma_C = 0.01  # pF
sigma_m = 0.01 / 1000  # gram → kg
sigma_x = (g / k_gemiddeld) * sigma_m

# Plot indeuking tegen capaciteit in pF
plt.plot(delta_x_spons, capaciteit_pF, 'r.')
plt.errorbar(delta_x_spons, capaciteit_pF, xerr=sigma_x, yerr=sigma_C, fmt='none', ecolor='red', elinewidth=1, capsize=3, label='Meetfout')
plt.plot(delta_x, C_pF)
plt.xlabel("Indeuking (m)")
plt.ylabel("Capaciteit (pF)")
plt.title("Indeuking vs Capaciteit")
plt.show()

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * verbetering 1
# Het geval is nu dat de zandzakken niet uniform op de spons drukken. De verbetering kan dan zijn dat we gebruik maken van massieve metalen gewichten die dezelfde afmetingen hebben als de vlakke platen van de condensator. Op deze manier drukken ze altijd uniform op de spons en kunnen we nauwkeurigere metingen doen.
# * verbetering 2
# Een mogelijke verbetering van de meetopstelling is het gebruiken van grotere condensatorplaten. De formule die wij gebruiken gaat ervan uit dat de platen heel groot zijn en dat het elektrisch veld alleen recht tussen de platen loopt. In werkelijkheid lopen er ook veldlijnen langs de randen van de platen. Daardoor wordt de gemeten capaciteit groter dan wat de formule voorspelt. Als we grotere platen gebruiken, wordt het effect van de randen kleiner en zullen de meetwaarden beter overeenkomen met het theoretische model.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](tudelftLogo.png)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij

#wij hebben als aanpassing van alle constante waardes 1 constante gemaakt alpha en deze gaan we fitten.

epsilon_0 = 8.854187817e-12
oppervlakte = 0.00992
afstand_0 = 1.2 / 100
k = k_gemiddeld
g = 9.81

# Gemeten data
gebruikte_massas = np.array([964, 1446.7, 2397.5, 2971.5, 3460.7, 4425.1, 5398.9, 6361.9]) / 1000
capaciteit = np.array([14.7, 16.9, 23.1, 26.4, 28.9, 32.6, 36.2, 40.2]) * 1e-12

# Indeuking en afstand gemeten punten
delta_x_meet = (gebruikte_massas * g) / k
afstand_meet = afstand_0 - delta_x_meet
afstand_meet[afstand_meet <= 0] = 1e-6

# Model: C = alpha / d
def model(d, alpha):
    return alpha / d

# Fit alpha
popt, pcov = curve_fit(model, afstand_meet, capaciteit)
alpha_fit = popt[0]

print(f"Gefitte alpha = {alpha_fit:.3e}")

# Theoretische curve maken
massa = np.linspace(0, 6, 200)
delta_x = (massa * g) / k
afstand = afstand_0 - delta_x
afstand[afstand <= 0] = 1e-6
C_fit = model(afstand, alpha_fit)

# Plot
plt.plot(delta_x, C_fit * 1e12, label="Theoretisch model (fit)")
plt.errorbar(delta_x_spons, capaciteit_pF, xerr=sigma_x, yerr=sigma_C, fmt='none', ecolor='red', elinewidth=1, capsize=3, label='meetgegevens met meetfouten')
plt.xlabel("Indeuking (m)")
plt.ylabel("Capaciteit (pF)")
plt.title("Indeuking vs Capaciteit")
plt.legend()
plt.show()
# Out:
# Gefitte alpha = 2.829e-13

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# Onze sensor is zeer geschikt om de veranderende capaciteit van een spons die wordt ingedrukt te meten. We hebben een duidelijke relatie gevonden tussen de indeuking van de spons en de gemeten capaciteit. De sensor is ook gevoelig genoeg om kleine veranderingen in de indeuking te detecteren, wat blijkt uit de meetgegevens. De verbetering die wij hebben doorgevoerd, namelijk de constantes in de formule te fitten in plaats van uit te gaan van bepaalde waardes, hebben ervoor gezorgd dat ons praktisch model meer overeenkomt met het theoretisch model. Er zit tevens nog wel een groot verschil tussen de twee modellen. Het blijkt dat het praktische model een stijlere lijn is, wat wil zeggen dat de sensor gevoeliger blijkt dan wij voorspeld hadden. Het theoretisch model gaat uit van ideale omstandigheden, ook op het vlak van meten. Dus in de praktijk worden ook verschijnselen zoals randeffecten wat een hogere gemeten capaciteit kan verklaren. Ook hebben wij zelf de veerconstante bepaald, het is ook mogeliojk dat hier een fout zit waardoor de modellen niet op elkaar lijken. We kunnen de vlakke plaat formule niet terug vinden in ons model.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# ![drie schetsen](foto_schetsen_synthese.jpeg)

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# ![scope meting 1](foto_opstelling.jpeg)
# ![scope meting 2](foto_apperatuur.jpeg)
#
# Dit zijn de oude foto's die verbeterd zijn nu. Om een of andere reden willen de nieuwe foto's niet laden maar die zijn wel in de map aanwezig. Deze foto's kloppen dus niet met de huidige opstelling.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 10 |20 |
# | gemiddelde capaciteit| 12.5 |40 |
# | maximale capaciteit| 15 |60 |

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij

#wij hebben als aanpassing van alle constante waardes 1 constante gemaakt alpha en deze gaan we fitten.

epsilon_0 = 8.854187817e-12
oppervlakte = 0.00992
afstand_0 = 1.2 / 100
k = k_gemiddeld
g = 9.81

# Gemeten data
gebruikte_massas = np.array([964, 1446.7, 2397.5, 2971.5, 3460.7, 4425.1, 5398.9, 6361.9]) / 1000
capaciteit = np.array([14.7, 16.9, 23.1, 26.4, 28.9, 32.6, 36.2, 40.2]) * 1e-12

# Indeuking en afstand gemeten punten
delta_x_meet = (gebruikte_massas * g) / k
afstand_meet = afstand_0 - delta_x_meet
afstand_meet[afstand_meet <= 0] = 1e-6

# Model: C = alpha / d
def model(d, alpha):
    return alpha / d

# Fit alpha
popt, pcov = curve_fit(model, afstand_meet, capaciteit)
alpha_fit = popt[0]

print(f"Gefitte alpha = {alpha_fit:.3e}")

# Theoretische curve maken
massa = np.linspace(0, 6, 200)
delta_x = (massa * g) / k
afstand = afstand_0 - delta_x
afstand[afstand <= 0] = 1e-6
C_fit = model(afstand, alpha_fit)

# Plot
plt.plot(delta_x, C_fit * 1e12, label="Theoretisch model (fit)")
plt.errorbar(delta_x_spons, capaciteit_pF, xerr=sigma_x, yerr=sigma_C, fmt='none', ecolor='red', elinewidth=1, capsize=3, label='meetgegevens met meetfouten')
plt.xlabel("Indeuking (m)")
plt.ylabel("Capaciteit (pF)")
plt.title("Indeuking vs Capaciteit")
plt.legend()
plt.show()
# Out:
# Gefitte alpha = 2.829e-13

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * verbetering 1
# Het geval is nu dat de zandzakken niet uniform op de spons drukken. De verbetering kan dan zijn dat we gebruik maken van massieve metalen gewichten die dezelfde afmetingen hebben als de vlakke platen van de condensator. Op deze manier drukken ze altijd uniform op de spons en kunnen we nauwkeurigere metingen doen.
# * verbetering 2
# Een mogelijke verbetering van de meetopstelling is het gebruiken van grotere condensatorplaten. De formule die wij gebruiken gaat ervan uit dat de platen heel groot zijn en dat het elektrisch veld alleen recht tussen de platen loopt. In werkelijkheid lopen er ook veldlijnen langs de randen van de platen. Daardoor wordt de gemeten capaciteit groter dan wat de formule voorspelt. Als we grotere platen gebruiken, wordt het effect van de randen kleiner en zullen de meetwaarden beter overeenkomen met het theoretische model.

# %% [markdown]
# Onze sensor is zeer geschikt om de veranderende capaciteit van een spons die wordt ingedrukt te meten. We hebben een duidelijke relatie gevonden tussen de indeuking van de spons en de gemeten capaciteit. De sensor is ook gevoelig genoeg om kleine veranderingen in de indeuking te detecteren, wat blijkt uit de meetgegevens. De verbetering die wij hebben doorgevoerd, namelijk de constantes in de formule te fitten in plaats van uit te gaan van bepaalde waardes, hebben ervoor gezorgd dat ons praktisch model meer overeenkomt met het theoretisch model. Er zit tevens nog wel een groot verschil tussen de twee modellen. Het blijkt dat het praktische model een stijlere lijn is, wat wil zeggen dat de sensor gevoeliger blijkt dan wij voorspeld hadden. Het theoretisch model gaat uit van ideale omstandigheden, ook op het vlak van meten. Dus in de praktijk worden ook verschijnselen zoals randeffecten wat een hogere gemeten capaciteit kan verklaren. Hieruit kunnen wij concluderen dat de vlakke plaat formule niet klopt voor onze sensor, maar dat we wel een bruikbaar model hebben gevonden dat de meetgegevens goed beschrijft.
